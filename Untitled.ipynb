# %%
Export["plot.cdf",CreateDocument[Plot3D[Cos[0.25((x/10)^2+(y/10)^2)],{x,-50,50},{y,-50,50},PlotStyle->LightBlue]]]
# Out:
# plot.cdf

# %%
100*Sin[x/10] + 1
# Out:
# Plot3D[f, {x, x   , x   }, {y, y   , y   }]
#                min   max        min   max
#
# >    generates a three-dimensional plot of f
#
# >     as a function of x and y. Plot3D[{f , f , …}, {x, x   , x   }, {y, y   , y   }]
#                                          1   2           min   max        min   max
#
# >        plots several functions. Plot3D[{…, w[f ], …}, …]
#                                                 i
#
# >         plots f  with features defined by the symbolic wrapper w
#                  i
#
# >          .Plot3D[…, {x, y} ∈ reg] takes variables {x, y}
#
#
# >             to be in the geometric region reg.
#
#
# Attributes[Plot3D]={Protected, ReadProtected}
